# %% [markdown]
# <a href="https://colab.research.google.com/github/Jay06eng/Machine-Learning/blob/main/LEC_5_Python_for_Data_Analytics_on_SuperStore_Data_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Python for Data Analytics**
#
# using [Superstore Marketing Campaign Dataset](https://www.kaggle.com/datasets/ahsan81/superstore-marketing-campaign-dataset)
#
# *PART 3*
#
# Incorporating statistical concepts and exploratory data analysis tools.
# ---

# %% [markdown]
# Import the necessary libraries:

# %% [markdown]
# 1. import pandas as pd:
#
# This line imports the Pandas library and assigns it the alias 'pd.' Pandas is a popular data manipulation and analysis library that provides DataFrame and Series data structures, making it easier to work with tabular data.
#
# 2. import numpy as np:
#
# This line imports the NumPy library and assigns it the alias 'np.' NumPy is a fundamental library for numerical computing in Python, providing support for multi-dimensional arrays and various mathematical functions.
#
# 3. import matplotlib.pyplot as plt:
#
# This line imports the pyplot module from the Matplotlib library and assigns it the alias 'plt.' Matplotlib is a widely-used library for creating static, animated, and interactive visualizations in Python. The 'plt' alias is a common convention for Matplotlib.
#
# 4. import seaborn as sns:
#
# This line imports the Seaborn library and assigns it the alias 'sns.' Seaborn is built on top of Matplotlib and provides a higher-level interface for creating informative and attractive statistical graphics. It simplifies the process of creating complex plots and visualizations.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing data
Data = 'SuperStore-Data.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(Data)

# Display the first few rows of the DataFrame
df
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation              D  84835.0        0
# 1         1        1961  Graduation              S  57091.0        0
# 2     10476        1958  Graduation              M  67267.0        0
# 3      1386        1967  Graduation              T  32474.0        1
# 4      5371        1989  Graduation              S  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2233  10142        1976         PhD              D  66476.0        0
# 2234   5263        1977    2n Cycle              M  31056.0        1
# 2235     22        1976  Graduation              D  46310.0        1
# 2236    528        1978  Graduation              M  65819.0        0
# 2237   4070        1969         PhD              M  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %% [markdown]
# ##Average/Mean

# %%
# Calculate the average of the columns
average_web = df['NumWebPurchases'].mean()
average_catalog = df['NumCatalogPurchases'].mean()
average_store = df['NumStorePurchases'].mean()

print(f'Average NumWebPurchases: {average_web}')
print(f'Average NumCatalogPurchases: {average_catalog}')
print(f'Average NumStorePurchases: {average_store}')
# Out:
# Average NumWebPurchases: 4.082216264521895
# Average NumCatalogPurchases: 2.663538873994638
# Average NumStorePurchases: 5.789991063449508

# %% [markdown]
# **FREQUENCY**
#
# # Calculate the frequency of values in the specified columnfrequency_table = df[column_name].value_counts()

# %%
# Calculate the frequency of values in the specified column
frequency_table = df['Education'].value_counts()
frequency_table
# Out:
# Education
# Graduation    1127
# PhD            484
# Master         370
# 2n Cycle       203
# Basic           54
# Name: count, dtype: int64

# %% [markdown]
# **Descriptive Statistics:**

# %% [markdown]
# 1. Count: Count represents the number of observations or data points in a dataset. It indicates the total number of values in the dataset, excluding missing or NaN (Not-a-Number) values.
#
# 2. Mean (Average): The mean is the arithmetic average of all the values in the dataset. It's calculated by adding up all the values and then dividing by the count. The mean provides a measure of the dataset's central tendency.
#
# 3. Standard Deviation (std): The standard deviation measures the degree of variation or dispersion in a dataset. It quantifies how spread out the values are from the mean. A higher standard deviation indicates greater variability.
#
# Easier guide to STANDARD DEVIATION:
# https://www.statology.org/what-is-a-good-standard-deviation/
#
# To clarify:
#
# FOR EXAMPLE: our unit is year, std is 8.
#
# If the mean is 2014, then, on average, you would expect most individual data points to fall within 8 units above or below this mean, which means they could range from 2006 to 2022 in this context.
#
# This doesn't mean that every data point falls within this range, but it's a measure of the typical or average variation from the mean in your dataset. Some data points may be further from the mean than 8 units, while others may be closer.
#
# The standard deviation quantifies the spread or dispersion of your data. A smaller standard deviation indicates that data points tend to be closer to the mean, while a larger standard deviation indicates that data points are more spread out from the mean.
#
# So, in summary, a standard deviation of 8 suggests that data points are, on average, 8 units above or below the mean, but individual data points may vary from this average.
#
# 4. Minimum (min): The minimum is the smallest value in the dataset. It represents the lowest data point in the distribution.
#
# 5. 25% (First Quartile): This value represents the 25th percentile of the data. It's the value below which 25% of the data falls. It's also known as the first quartile (Q1).
#
# 6. 50% (Median or Second Quartile): The 50th percentile, also known as the median or second quartile (Q2), is the middle value when the data is sorted in ascending order. It divides the dataset into two equal halves.
#
# 7. 75% (Third Quartile): This value represents the 75th percentile of the data. It's the value below which 75% of the data falls. It's also known as the third quartile (Q3).
#
# 8. Maximum (max): The maximum is the largest value in the dataset. It represents the highest data point in the distribution.

# %%
# Descriptive statistics
desc_stats = df.describe()

# Information about the DataFrame
info = df.info()

# Display the results
print(desc_stats)
print(info)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2238 entries, 0 to 2237
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2238 non-null   int64
#  1   Year_Birth           2238 non-null   int64
#  2   Education            2238 non-null   object
#  3   Marital_Status       2238 non-null   object
#  4   Income               2214 non-null   float64
#  5   Kidhome              2238 non-null   int64
#  6   Teenhome             2238 non-null   int64
#  7   Dt_Customer          2238 non-null   object
#  8   Recency              2238 non-null   int64
#  9   MntWines             2238 non-null   int64
#  10  MntFruits            2238 non-null   int64
#  11  MntMeatProducts      2238 non-null   int64
#  12  MntFishProducts      2238 non-null   int64
#  13  MntSweetProducts     2238 non-null   int64
#  14  MntGoldProds         2238 non-null   int64
# ...

# %% [markdown]
# **Cross-Tabulation:**

# %% [markdown]
# Cross-tabulation, often referred to as a contingency table or crosstab, is a statistical technique used to summarize and analyze the relationship between **two categorical variables.** It provides a way to examine how the values of one variable are distributed across the categories of another variable. Here's a brief explanation:
#
# ***Variables:*** In a crosstab, you have two categorical variables, typically referred to as the row variable and the column variable.
#
# ***Frequency Counts:*** The main purpose of cross-tabulation is to calculate and display the frequency counts of how many observations fall into each combination of categories for the two variables. Each cell in the table represents a unique combination of category values.
#
# ***Summarizing Relationships:*** By creating a cross-tabulation, you can quickly see how the distribution of one variable varies or depends on the categories of the other variable. It helps identify patterns, associations, or dependencies between the two variables.
#
# *Example:* For instance, if you have data on the gender and buying preferences of customers, a cross-tabulation could show you how many male and female customers prefer different product categories. This can help in market segmentation and targeted marketing.

# %%
cross_tab = pd.crosstab(df['Education'], df['Marital_Status'])

# Display the cross-tabulation
print(cross_tab)
# Out:
# Marital_Status    D    M  Other    S    T   W
# Education
# 2n Cycle         23   81      0   37   57   5
# Basic             1   20      0   18   14   1
# Graduation      119  433      2  252  286  35
# Master           37  138      2   75  106  12
# PhD              52  192      1   98  117  24

# %% [markdown]
# ```
# # Add margins (Grand Totals)
# cross_tab_with_totals = pd.crosstab(df['Education'], df['Marital_Status'], margins=True, margins_name='Grand Total')
#
# # Display the crosstab with Grand Totals
# print(cross_tab_with_totals)
# ```

# %%
# Calculate the average of the columns
average_web = df['NumWebPurchases'].mean()
average_catalog = df['NumCatalogPurchases'].mean()
average_store = df['NumStorePurchases'].mean()

print(f'Average NumWebPurchases: {average_web}')
print(f'Average NumCatalogPurchases: {average_catalog}')
print(f'Average NumStorePurchases: {average_store}')
# Out:
# Average NumWebPurchases: 4.082216264521895
# Average NumCatalogPurchases: 2.663538873994638
# Average NumStorePurchases: 5.789991063449508

# %% [markdown]
# # MAKING A TABLE INVOLVING THE MEAN FUNCTION

# %%
# Calculate the averages for 'NumDealsPurchases' and 'NumCatalogPurchases'
averages = df[['Education', 'NumDealsPurchases', 'NumCatalogPurchases', 'NumStorePurchases']].groupby('Education').mean().reset_index()

# Print the resulting table
print(averages)
# Out:
#     Education  NumDealsPurchases  NumCatalogPurchases  NumStorePurchases
# 0    2n Cycle           2.246305             2.320197           5.507389
# 1       Basic           1.796296             0.481481           2.851852
# 2  Graduation           2.309672             2.725821           5.829636
# 3      Master           2.427027             2.570270           5.897297
# 4         PhD           2.363636             2.977273           6.061983

# %%
averages = df.groupby(['Education', 'Marital_Status'])[['NumDealsPurchases', 'NumCatalogPurchases', 'NumStorePurchases']].mean().reset_index()

# Print the resulting table
print(averages)
# Out:
#      Education Marital_Status  NumDealsPurchases  NumCatalogPurchases  \
# 0     2n Cycle              D           2.347826             2.434783
# 1     2n Cycle              M           2.123457             2.111111
# 2     2n Cycle              S           1.810811             2.540541
# 3     2n Cycle              T           2.684211             2.350877
# 4     2n Cycle              W           2.000000             3.200000
# 5        Basic              D           2.000000             0.000000
# 6        Basic              M           1.800000             0.400000
# 7        Basic              S           2.222222             0.666667
# 8        Basic              T           1.285714             0.357143
# 9        Basic              W           1.000000             1.000000
# 10  Graduation              D           2.302521             2.789916
# 11  Graduation              M           2.346420             2.607390
# ...

# %%
averages = df.groupby(
    ['Education', 'Marital_Status'])['Income'].mean().reset_index()

# Print the resulting table
print(averages)
# Out:
#      Education Marital_Status        Income
# 0     2n Cycle              D  49395.130435
# 1     2n Cycle              M  46201.100000
# 2     2n Cycle              S  53673.944444
# 3     2n Cycle              T  44736.410714
# 4     2n Cycle              W  51392.200000
# 5        Basic              D   9548.000000
# 6        Basic              M  21960.500000
# 7        Basic              S  18238.666667
# 8        Basic              T  21240.071429
# 9        Basic              W  22123.000000
# 10  Graduation              D  54526.042017
# 11  Graduation              M  50800.258741
# 12  Graduation          Other  56710.000000
# 13  Graduation              S  51322.182927
# 14  Graduation              T  55758.480702
# 15  Graduation              W  54976.657143
# 16      Master              D  50331.945946
# 17      Master              M  53286.028986
# 18      Master          Other  63409.000000
# 19      Master              S  53530.560000
# ...

# %%
# Calculate the averages for 'NumDealsPurchases' and 'NumCatalogPurchases'
averages = df[['Education', 'NumDealsPurchases', 'NumCatalogPurchases']].groupby('Education').mean().reset_index()

averages
# Out:
#     Education  NumDealsPurchases  NumCatalogPurchases
# 0    2n Cycle           2.246305             2.320197
# 1       Basic           1.796296             0.481481
# 2  Graduation           2.309672             2.725821
# 3      Master           2.427027             2.570270
# 4         PhD           2.363636             2.977273

# %% [markdown]
# # Python table to Excel

# %%
averages.to_excel('averages.xlsx', index=False)

# %% [markdown]
#  averages.to_excel('averages.xlsx', index=False) saves the DataFrame averages to an Excel file named "averages.xlsx" without including the index column in the saved file.

# %% [markdown]
# **Visualization:**

# %% [markdown]
# 1. HISTOGRAM (of income)
#
# A histogram is a graphical representation of the distribution of a dataset. It's used to visualize the frequency or count of data points falling into specific intervals, or "bins," along a continuous or numerical data axis. Histograms are particularly useful for understanding the shape, central tendency, and spread of a dataset. They are well-suited for visualizing and analyzing data with the following characteristics:
#
# Numerical Data: Histograms are primarily designed for numerical or continuous data types. They work best with data that can be measured on a scale, such as age, income, height, or temperature.
#
# Univariate Analysis: Histograms are used for analyzing and visualizing a single variable at a time. They provide insights into the distribution of values within that variable.

# %% [markdown]
# ![Screenshot 2023-09-14 085818.png](data:image/png;base64,...)

# %%
# Create a new figure for the histogram with a specified size
plt.figure(figsize=(10, 6))

# Create a histogram plot for the 'Income' column in the DataFrame
# 'bins=30' specifies the number of bins (intervals) for the histogram
# 'kde=True' adds a kernel density estimate to the plot for a smoother curve
sns.histplot(df['Income'], bins=50, kde=True)

# Label the x-axis as 'Income'
plt.xlabel('Income')

# Label the y-axis as 'Frequency'
plt.ylabel('Frequency')

# Set the title of the plot to 'Income Distribution'
plt.title('Income Distribution')

# Display the histogram plot
plt.show()

# %% [markdown]
# 2. Bar Plot (for Education Levels):

# %% [markdown]
# A bar plot, also known as a bar chart, is a graphical representation of data using rectangular bars or columns. Each bar represents a category or group, and the bar's length or height is proportional to the data it represents. Bar plots are used to compare data across categories, display frequency distributions, and visualize part-to-whole relationships. They are especially useful for summarizing and communicating categorical data effectively.

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Education')
plt.xlabel('Education')
plt.ylabel('Count')
plt.title('Education Levels')
plt.xticks(rotation=45)
plt.show()

# %%
# Calculate the percentages for Marital Status
marital_status_percentages = (df['Marital_Status'].value_counts() / len(df)) * 100

# Create a bar chart with percentages on the y-axis
plt.figure(figsize=(8, 5))
sns.barplot(x=marital_status_percentages.index, y=marital_status_percentages.values)
plt.xlabel('Marital Status')
plt.ylabel('Percentage')
plt.title('Marital Status Distribution')
plt.xticks(rotation=45)
plt.ylim(0, 100)  # Set the y-axis limit to ensure percentages are displayed correctly
plt.show()

# %% [markdown]
# **multiseries bar chart**

# %%
# Create a new DataFrame with columns for education and the purchase variables
purchase_df_averages = averages[['Education', 'NumDealsPurchases', 'NumCatalogPurchases']]

# Group the data by education and calculate the sum of purchases for each category
purchase_grouped_averages = purchase_df_averages.groupby('Education').sum().reset_index()

# Melt the DataFrame to convert it to long format for plotting
purchase_melted_averages = purchase_grouped_averages.melt(
    id_vars='Education', var_name='PurchaseType', value_name='Average')

# Create a stacked bar chart
plt.figure(figsize=(12, 8))
sns.barplot(data=purchase_melted_averages, x='Education', y='Average', hue='PurchaseType', palette='viridis')

# Add labels and title
plt.xlabel('Education Level')
plt.ylabel('Average')
plt.title('Multiseries Bar Chart of Purchases by Education Level')

# Show the plot
plt.xticks(rotation=45)
plt.legend(title='Purchase Type')
plt.show()

# %%
# Create a new DataFrame with columns for education and the purchase variables
purchase_df = df[['Education', 'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases']]

# Group the data by education and calculate the sum of purchases for each category
purchase_grouped = purchase_df.groupby('Education').sum().reset_index()

# Melt the DataFrame to convert it to long format for plotting
purchase_melted = purchase_grouped.melt(id_vars='Education', var_name='PurchaseType', value_name='Count')

# Create a stacked bar chart
plt.figure(figsize=(12, 8))
sns.barplot(data=purchase_melted, x='Education', y='Count', hue='PurchaseType', palette='viridis')

# Add labels and title
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.title('Multiseries Bar Chart of Purchases by Education Level')

# Show the plot
plt.xticks(rotation=45)
plt.legend(title='Purchase Type')
plt.show()

# %% [markdown]
# **HISTOGRAM VS. BAR CHART**

# %% [markdown]
# Histogram is for continuous variable like income
# Bar chart is for categorical variable like education level

# %% [markdown]
# 3. Box Plot
#
# THE PICTURE BELOW SHOWS PARTS OF IT.

# %% [markdown]
# ![xBoxPlot.GIF.pagespeed.ic.gh-SaNpKnn.png](data:image/png;base64,...)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Education', y='Income')
plt.xlabel('Education')
plt.ylabel('Income')
plt.title('Income by Education Level')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # DATA PRE-PROCESSING

# %% [markdown]
# **REMOVING ROWS WITH SPECIFIC OBSERVATIONS**
#
# Sometimes we need to remove records that don't make sense.
#
# Example:
#
# Since we see a major outlier makiing our boxplots ugly, we filter it out. Since the other outliers seem influential, we keep them.
#
# From the descriptive statistics, we know that max income is 666666.000000 and that is our major outlier affecting our information drastically. If we wish to remove that, we can filter it out.

# %%
# Define the value to filter on
income_value_to_delete = 666666.000000

# Create a new DataFrame excluding rows with the specified income value
filtered_data = df[df['Income'] != income_value_to_delete]

# Display the filtered DataFrame
filtered_data.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation              D  84835.0        0         0
# 1      1        1961  Graduation              S  57091.0        0         0
# 2  10476        1958  Graduation              M  67267.0        0         1
# 3   1386        1967  Graduation              T  32474.0        1         1
# 4   5371        1989  Graduation              S  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=filtered_data, x='Education', y='Income')
plt.xlabel('Education')
plt.ylabel('Income')
plt.title('Income by Education Level')
plt.xticks(rotation=45)
plt.show()

# %%
filtered_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2237 entries, 0 to 2237
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2237 non-null   int64
#  1   Year_Birth           2237 non-null   int64
#  2   Education            2237 non-null   object
#  3   Marital_Status       2237 non-null   object
#  4   Income               2213 non-null   float64
#  5   Kidhome              2237 non-null   int64
#  6   Teenhome             2237 non-null   int64
#  7   Dt_Customer          2237 non-null   object
#  8   Recency              2237 non-null   int64
#  9   MntWines             2237 non-null   int64
#  10  MntFruits            2237 non-null   int64
#  11  MntMeatProducts      2237 non-null   int64
#  12  MntFishProducts      2237 non-null   int64
#  13  MntSweetProducts     2237 non-null   int64
#  14  MntGoldProds         2237 non-null   int64
# ...

# %% [markdown]
# Now we see the median lines and the boxplot information better.
#
# You can do further research on when you can remove your outliers. But here is my guide:

# %% [markdown]
# **Reasons to Remove Outliers:**
#
#   Data Quality: Outliers may result from errors in data collection or recording, and they can represent data quality issues. Removing them can help improve the overall quality of your dataset.
#
#   Statistical Assumptions: Many statistical methods assume that data is normally distributed or follows certain patterns. Outliers can violate these assumptions, leading to biased or inaccurate results.
#
#   Visualizations: Outliers can distort data visualizations, making it challenging to interpret or communicate results effectively. Removing them can lead to clearer and more informative visualizations.
#
#
# **When to Remove Outliers:**
#
#   Domain Knowledge: Consider the context and domain knowledge. Some outliers may be valid and meaningful data points, especially in certain research or industry-specific contexts. Be cautious when removing outliers and ensure it aligns with the problem you're trying to solve.
#
#   Data Goals: The decision to remove outliers should be based on the goals of your analysis. If your goal is to understand the overall trend and characteristics of the data, removing outliers might be appropriate. However, if you want to specifically analyze extreme values, keeping them may be more relevant.
#
#
# **How to Remove Outliers:**
#
#   Deletion: Simply remove the outlier data points from the dataset. This is the most straightforward method but can result in loss of information.
#
#   Transformation: Apply mathematical transformations to the data (e.g., logarithmic transformation) to reduce the impact of outliers without completely removing them.
#
#   Imputation: Replace outliers with more typical values, often using techniques like mean imputation or interpolation.

# %% [markdown]
# You can also set a range to remove outliers: this case I filtered out the dataframe to only keep the rows with income less than 140000

# %%
# Create a new DataFrame excluding rows with the specified income value
filtered_data2 = df[df['Income'] < 140000]

# Display the filtered DataFrame
filtered_data2.head(8)
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation              D  84835.0        0         0
# 1      1        1961  Graduation              S  57091.0        0         0
# 2  10476        1958  Graduation              M  67267.0        0         1
# 3   1386        1967  Graduation              T  32474.0        1         1
# 4   5371        1989  Graduation              S  21474.0        1         0
# 5   7348        1958         PhD              S  71691.0        0         0
# 6   4073        1954    2n Cycle              M  63564.0        0         0
# 7   1991        1967  Graduation              T  44931.0        0         1
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# ...

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=filtered_data2, x='Education', y='Income')
plt.xlabel('Education')
plt.ylabel('Income')
plt.title('Income by Education Level')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # GUIDE TO REPLACE CATEGORICAL TO NUMERICAL DATA

# %% [markdown]
# Some statistical methods requires data to be numerical, you can use mapping to convert categorical data to numerical data this way:

# %%
# Define a mapping of categories to numerical labels
education_mapping = {
    '2n Cycle': 0,
    'Basic': 1,
    'Graduation': 2,
    'Master': 3,
    'PhD': 4
}

# Apply label encoding to the 'Education' column in your DataFrame 'df'
df['Education'] = df['Education'].map(education_mapping)

# Display the DataFrame 'df' with categorical data replaced by numerical values
df
# Out:
#          Id  Year_Birth  Education Marital_Status   Income  Kidhome  Teenhome  \
# 0      1826        1970          2              D  84835.0        0         0
# 1         1        1961          2              S  57091.0        0         0
# 2     10476        1958          2              M  67267.0        0         1
# 3      1386        1967          2              T  32474.0        1         1
# 4      5371        1989          2              S  21474.0        1         0
# ...     ...         ...        ...            ...      ...      ...       ...
# 2233  10142        1976          4              D  66476.0        0         1
# 2234   5263        1977          0              M  31056.0        1         0
# 2235     22        1976          2              D  46310.0        1         0
# 2236    528        1978          2              M  65819.0        0         0
# 2237   4070        1969          4              M  94871.0        0         2
#
# ...

# %% [markdown]
# # ANALYTICS GUIDE
#
#
# *   Analyze the descriptive statistics to understand the central tendency, dispersion, and other statistical properties of your data.
#
# *   Examine cross-tabulation results to see how different categorical variables are related.
#
# *   Interpret visualizations to identify trends and patterns in your data. For example, the income distribution or the relationship between education and income.

# %% [markdown]
# # PIE CHART

# %% [markdown]
# **PIE CHART WITH SINGLE COLUMN INVOLVED**

# %%
# Calculate the counts for each type of purchase
counts = [df['MntMeatProducts'].sum(),
          df['MntFishProducts'].sum()]

labels = ['MntMeatProducts', 'MntFishProducts']
plt.figure(figsize=(6, 6))
plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Type of Purchases')
plt.show()

# %% [markdown]
# #GETTING TOTAL PURCHASES

# %% [markdown]
# **PIE CHART WITH TWO COLUMNs AND CONDITION INVOLVED**

# %% [markdown]
# This code is for getting the sum involving two columns
#
#     # Calculate total fruit purchases for people with and without kids at home
#     total_fruits_with_kids = df[df['Kidhome'] >= 1]['MntFruits'].sum()
#     total_fruits_without_kids = df[df['Kidhome'] == 0]['MntFruits'].sum()

# %%
# Calculate total fruit purchases for people with and without kids at home
total_fruits_with_kids = df[df['Kidhome'] >= 1]['MntFruits'].sum()
total_fruits_without_kids = df[df['Kidhome'] == 0]['MntFruits'].sum()

print(total_fruits_with_kids)
print(total_fruits_without_kids)


# Create a list of purchase totals and corresponding labels
purchase_totals = [total_fruits_with_kids, total_fruits_without_kids]
purchase_labels = ['With Kids', 'Without Kids']

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(purchase_totals, labels=purchase_labels, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Fruit Purchases by Presence of Kids at Home')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Show the pie chart
plt.show()

# Draw conclusions
if total_fruits_with_kids > total_fruits_without_kids:
    conclusion = "People with kids at home buy more fruits."
else:
    conclusion = "People without kids at home buy more fruits."

print(conclusion)
# Out:
# 7982
# 50929
# People without kids at home buy more fruits.

# %% [markdown]
# GETTING CASES INSTEAD OF SUM

# %%
# Count the number of cases where people with kids bought fruits (Kidhome >= 1 and MntFruits > 0)
count_with_kids_and_fruit = ((df['Kidhome'] >= 1) & (df['MntFruits'] > 0)).sum()

# Count the number of cases where people without kids bought fruits (Kidhome == 0 and MntFruits > 0)
count_without_kids_and_fruit = ((df['Kidhome'] == 0) & (df['MntFruits'] > 0)).sum()

print("Count of cases where people with kids bought fruits:", count_with_kids_and_fruit)
print("Count of cases where people without kids bought fruits:", count_without_kids_and_fruit)

# Create a list of purchase totals and corresponding labels
purchase_totals = [count_with_kids_and_fruit, count_without_kids_and_fruit]
purchase_labels = ['With Kids', 'Without Kids']

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(purchase_totals, labels=purchase_labels, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Cases with Fruit Purchases by Presence of Kids at Home')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Show the pie chart
plt.show()
# Out:
# Count of cases where people with kids bought fruits: 715
# Count of cases where people without kids bought fruits: 1123

# %% [markdown]
# # LINE CHART

# %%
# Group the data by 'Year_Birth' and calculate the mean 'Recency' for each year
avg_recency_by_year = df.groupby('Year_Birth')['Recency'].mean()

# Reset the index to make 'Year_Birth' a regular column
avg_recency_by_year = avg_recency_by_year.reset_index()

# Create a line chart
plt.figure(figsize=(10, 6))
plt.plot(avg_recency_by_year['Year_Birth'], avg_recency_by_year['Recency'], marker='o', linestyle='-')
plt.xlabel('Year of Birth')
plt.ylabel('Average Recency')
plt.title('Average Recency by Year of Birth')
plt.grid(True)

# Show the line chart
plt.show()
