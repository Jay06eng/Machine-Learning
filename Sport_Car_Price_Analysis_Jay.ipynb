# %% [markdown]
# <a href="https://colab.research.google.com/github/Jay06eng/Machine-Learning/blob/main/Sport_Car_Price_Analysis_Jay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧪 Python Lab Activity: Exploring Sports Car Prices
#
# This dataset contains information about the prices of different sports cars from various manufacturers. The dataset includes the make and model of the car, the year of production, the engine size, the horsepower, the torque, the 0-60 MPH time, and the price in USD. The dataset is useful for analyzing the prices of different sports cars and identifying trends in the market.
#
# Columns
#
# 1. Car Make: The make of the sports car, which represents the brand or company that produced the car. Examples of car makes in this dataset include Porsche, Lamborghini, Ferrari, Audi, and McLaren.
#
# 2. Car Model: The model of the sports car, which represents the specific version or variant of the car produced by the manufacturer. Examples of car models in this dataset include 911, Huracan, 488 GTB, R8, 720S, M8, AMG GT, Corvette, Mustang Shelby GT500, and GT-R Nismo.
#
# 3. Year: The year of production of the sports car, which indicates the model year when the car was first introduced or made available for purchase.
#
# 4. Engine Size (L): The size of the sports car's engine in liters, which represents the volume of the engine's cylinders. A larger engine size typically indicates higher power and performance. Engine sizes in this dataset range from 2.0L to 8.0L, with some cars having electric motors instead.
#
# 5. Horsepower: The horsepower of the sports car, which represents the power output of the car's engine. Higher horsepower typically indicates faster acceleration and higher top speed. Horsepower values in this dataset range from 300 to 1479.
#
# 6. Torque (lb-ft): The torque of the sports car in pound-feet, which represents the rotational force generated by the engine. Higher torque values typically indicate stronger acceleration and better handling. Torque values in this dataset range from 270 to 1180.
#
# 7. 0-60 MPH Time (seconds): The time it takes for the sports car to accelerate from 0 to 60 miles per hour, which is a common measure of acceleration and performance. Lower 0-60 MPH times typically indicate faster acceleration and better performance. 0-60 MPH times in this dataset range from 1.85 to 5.3 seconds.
#
# 8. Price (in USD): The price of the sports car in US dollars, which represents the cost of purchasing the car. Prices in this dataset range from 25,000 USD to 3,000,000 USD.

# %% [markdown]
# ## 📂 1. Import Libraries and Load the Dataset
#  Import libraries
#
#   Load dataset
#
#
#   Display first 10 rows

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv("Sport car price.csv")

df.head(10)
# Out:
#         Car Make             Car Model  Year Engine Size (L) Horsepower  \
# 0        Porsche                   911  2022               3        379
# 1    Lamborghini               Huracan  2021             5.2        630
# 2        Ferrari               488 GTB  2022             3.9        661
# 3           Audi                    R8  2022             5.2        562
# 4        McLaren                  720S  2021               4        710
# 5            BMW                    M8  2022             4.4        617
# 6  Mercedes-Benz                AMG GT  2021               4        523
# 7      Chevrolet              Corvette  2021             6.2        490
# 8           Ford  Mustang Shelby GT500  2022             5.2        760
# 9         Nissan            GT-R Nismo  2021             3.8        600
#
#   Torque (lb-ft) 0-60 MPH Time (seconds) Price (in USD)
# 0            331                       4        101,200
# 1            443                     2.8        274,390
# ...

# %% [markdown]
# ## 🔍 2. Explore the Dataset
#
#  Display number of rows and columns

# %%
df.shape
# Out:
# (1007, 8)

# %% [markdown]
# Display info about columns and data types

# %%
df.columns
# Out:
# Index(['Car Make', 'Car Model', 'Year', 'Engine Size (L)', 'Horsepower',
#        'Torque (lb-ft)', '0-60 MPH Time (seconds)', 'Price (in USD)'],
#       dtype='object')

# %%
df.rename(columns={
    'Car Make': 'Brand',
    'Car Model': 'Model',
    'Engine Size (L)': 'Engine',
    '0-60 MPH Time (seconds)': '0-60',
    'Torque (lb-ft)': 'Torque',
    'Price (in USD)': 'Price',
}, inplace=True)
df.columns
# Out:
# Index(['Brand', 'Model', 'Year', 'Engine', 'Horsepower', 'Torque', '0-60',
#        'Price'],
#       dtype='object')

# %%
df
# Out:
#             Brand    Model  Year          Engine Horsepower Torque  0-60  \
# 0         Porsche      911  2022               3        379    331     4
# 1     Lamborghini  Huracan  2021             5.2        630    443   2.8
# 2         Ferrari  488 GTB  2022             3.9        661    561     3
# 3            Audi       R8  2022             5.2        562    406   3.2
# 4         McLaren     720S  2021               4        710    568   2.7
# ...           ...      ...   ...             ...        ...    ...   ...
# 1002   Koenigsegg    Jesko  2022               5       1280   1106   2.5
# 1003        Lotus    Evija  2021  Electric Motor       1972   1254     2
# 1004      McLaren    Senna  2021               4        789    590   2.7
# 1005       Pagani   Huayra  2021               6        764    738     3
# 1006        Rimac   Nevera  2021  Electric Motor       1888   1696  1.85
#
#           Price
# 0       101,200
# 1       274,390
# 2       333,750
# 3       142,700
# ...

# %%
df.dtypes
# Out:
# Brand         object
# Model         object
# Year           int64
# Engine        object
# Horsepower    object
# Torque        object
# 0-60          object
# Price         object
# dtype: object

# %% [markdown]
# Check for missing values

# %%
df.isna().sum()
# Out:
# Brand          0
# Model          0
# Year           0
# Engine        10
# Horsepower     0
# Torque         3
# 0-60           0
# Price          0
# dtype: int64

# %% [markdown]
# Show summary statistics

# %%
df.describe()
# Out:
#               Year
# count  1007.000000
# mean   2021.201589
# std       2.019802
# min    1965.000000
# 25%    2021.000000
# 50%    2021.000000
# 75%    2022.000000
# max    2023.000000

# %% [markdown]
# ## 🧹 3. Data Cleaning and Preparation
#
# Handle missing values (fill or drop)

# %%
df.isna().sum()
# Out:
# Brand          0
# Model          0
# Year           0
# Engine        10
# Horsepower     0
# Torque         3
# 0-60           0
# Price          0
# dtype: int64

# %%
df.dropna(subset = ['Torque','Engine'], inplace=True)

# %%
df.isna().sum()
# Out:
# Brand         0
# Model         0
# Year          0
# Engine        0
# Horsepower    0
# Torque        0
# 0-60          0
# Price         0
# dtype: int64

# %% [markdown]
# Convert categorical columns to proper types (if applicable)

# %%
df.dtypes
# Out:
# Brand         object
# Model         object
# Year           int64
# Engine        object
# Horsepower    object
# Torque        object
# 0-60          object
# Price         object
# dtype: object

# %%
df2 = df[df['Engine'].astype(str).str.contains('[^0-9.]')]
df2[df2['Engine'].astype(str).str.contains('[^0-9.]')]
# Out:
#             Brand                      Model  Year                Engine  \
# 26          Rimac                     Nevera  2022              Electric
# 37        Porsche                  Taycan 4S  2022        Electric Motor
# 42            BMW                         i8  2020        1.5 + Electric
# 97          Rimac                     Nevera  2022              Electric
# 99          Tesla                   Roadster  2022              Electric
# 185       Porsche                     Taycan  2021              Electric
# 278         Rimac                      C_Two  2022              Electric
# 280   Pininfarina                   Battista  2022              Electric
# 299       Porsche                     Taycan  2022              Electric
# 300         Tesla                    Model S  2022              Electric
# 305       Porsche             Taycan Turbo S  2021              Electric
# 320         Tesla              Model S Plaid  2021              Electric
# ...

# %%
Special_Engine = df['Engine'].astype(str).str.contains('[^0-9.]').sum()
Special_Engine
# Out:
# np.int64(47)

# %%
Special_Horsepower = df['Horsepower'].astype(str).str.contains('[^0-9.]').sum()
Special_Horsepower
# Out:
# np.int64(7)

# %%
Special_Torque = df['Torque'].astype(str).str.contains('[^0-9.]').sum()
Special_Torque
# Out:
# np.int64(5)

# %%
Special_0_60 = df['0-60'].astype(str).str.contains('[^0-9.]').sum()
Special_0_60
# Out:
# np.int64(1)

# %%
Special_Price = df['Price'].astype(str).str.contains('[^0-9.]').sum()
Special_Price
# Out:
# np.int64(995)

# %%
df['Horsepower'] = pd.to_numeric(df['Horsepower'], errors='coerce')
df['Torque'] = pd.to_numeric(df['Torque'], errors='coerce')
df['0-60'] = pd.to_numeric(df['0-60'], errors='coerce')
df = df.dropna(subset=['Horsepower','Torque','0-60'])

# %%
df['Price'] = df['Price'].str.replace(',','').astype('float')

# %%
df.dtypes
# Out:
# Brand          object
# Model          object
# Year            int64
# Engine         object
# Horsepower    float64
# Torque        float64
# 0-60          float64
# Price         float64
# dtype: object

# %% [markdown]
# ## 🔧 4. Feature Engineering
#
# # Create a new column Price_Category and categorize the car prices using the following intervals:
#
# 10,000 - 30,000 = Budget
#
# 30,001 - 60,000 = Mid-Range
#
# 60,001 - 100,000 = Premium
#
# 100,000+ = Luxury

# %%
df['Price_Category'] = pd.cut(df['Price'], bins=[0, 30000, 60000, 100000, float('inf')],
                              labels=['Budget', 'Mid-Range', 'Premium', 'Luxury'])

df.head()
# Out:
#          Brand    Model  Year Engine  Horsepower  Torque  0-60     Price  \
# 0      Porsche      911  2022      3       379.0   331.0   4.0  101200.0
# 1  Lamborghini  Huracan  2021    5.2       630.0   443.0   2.8  274390.0
# 2      Ferrari  488 GTB  2022    3.9       661.0   561.0   3.0  333750.0
# 3         Audi       R8  2022    5.2       562.0   406.0   3.2  142700.0
# 4      McLaren     720S  2021      4       710.0   568.0   2.7  298000.0
#
#   Price_Category
# 0         Luxury
# 1         Luxury
# 2         Luxury
# 3         Luxury
# 4         Luxury

# %% [markdown]
# # Create 2 new columns Engine_Type and Engine_Size for gas engines

# %%
df['Engine_Size'] = np.where(
    df['Engine'].astype(str).str.replace('.', '', 1).str.isnumeric(),
    df['Engine'].astype(float, errors='ignore'),
    0
)
df['Engine_Size'] = df['Engine_Size'].astype(float)
df
# Out:
#             Brand    Model  Year          Engine  Horsepower  Torque  0-60  \
# 0         Porsche      911  2022               3       379.0   331.0  4.00
# 1     Lamborghini  Huracan  2021             5.2       630.0   443.0  2.80
# 2         Ferrari  488 GTB  2022             3.9       661.0   561.0  3.00
# 3            Audi       R8  2022             5.2       562.0   406.0  3.20
# 4         McLaren     720S  2021               4       710.0   568.0  2.70
# ...           ...      ...   ...             ...         ...     ...   ...
# 1002   Koenigsegg    Jesko  2022               5      1280.0  1106.0  2.50
# 1003        Lotus    Evija  2021  Electric Motor      1972.0  1254.0  2.00
# 1004      McLaren    Senna  2021               4       789.0   590.0  2.70
# 1005       Pagani   Huayra  2021               6       764.0   738.0  3.00
# 1006        Rimac   Nevera  2021  Electric Motor      1888.0  1696.0  1.85
#
#           Price Price_Category  Engine_Size
# ...

# %%
df['Engine_Type'] = np.where(df['Engine'].astype(str).str.replace('.', '', 1).str.isdigit(),
                             'Gas', 'Electric/Hybrid')
df
# Out:
#             Brand    Model  Year          Engine  Horsepower   Torque  0-60  \
# 0         Porsche      911  2022               3      379.00   331.00  4.00
# 1     Lamborghini  Huracan  2021             5.2      630.00   443.00  2.80
# 2         Ferrari  488 GTB  2022             3.9      661.00   561.00  3.00
# 3            Audi       R8  2022             5.2      562.00   406.00  3.20
# 4         McLaren     720S  2021               4      710.00   568.00  2.70
# ...           ...      ...   ...             ...         ...      ...   ...
# 1002   Koenigsegg    Jesko  2022               5    1,280.00 1,106.00  2.50
# 1003        Lotus    Evija  2021  Electric Motor    1,972.00 1,254.00  2.00
# 1004      McLaren    Senna  2021               4      789.00   590.00  2.70
# 1005       Pagani   Huayra  2021               6      764.00   738.00  3.00
# 1006        Rimac   Nevera  2021  Electric Motor    1,888.00 1,696.00  1.85
#
# ...

# %% [markdown]
# # Create new column for car age (as of end of 2025)

# %%
df['Car_Age'] = 2025 - df['Year'].astype('int64')
df
# Out:
#             Brand    Model  Year          Engine  Horsepower   Torque  0-60  \
# 0         Porsche      911  2022               3      379.00   331.00  4.00
# 1     Lamborghini  Huracan  2021             5.2      630.00   443.00  2.80
# 2         Ferrari  488 GTB  2022             3.9      661.00   561.00  3.00
# 3            Audi       R8  2022             5.2      562.00   406.00  3.20
# 4         McLaren     720S  2021               4      710.00   568.00  2.70
# ...           ...      ...   ...             ...         ...      ...   ...
# 1002   Koenigsegg    Jesko  2022               5    1,280.00 1,106.00  2.50
# 1003        Lotus    Evija  2021  Electric Motor    1,972.00 1,254.00  2.00
# 1004      McLaren    Senna  2021               4      789.00   590.00  2.70
# 1005       Pagani   Huayra  2021               6      764.00   738.00  3.00
# 1006        Rimac   Nevera  2021  Electric Motor    1,888.00 1,696.00  1.85
#
# ...

# %% [markdown]
# ## 📊 5. Exploratory Data Analysis (EDA)
# 5.1 Show the Average price by Car Make (Brand) sorted from highest to lowest

# %%
df.groupby('Brand')['Price'].mean().sort_values(ascending=False)
# Out:
# Brand
# Bugatti         3,263,409.09
# Koenigsegg      2,906,666.67
# Pagani          2,791,666.67
# Pininfarina     2,500,000.00
# Rimac           2,400,000.00
# W Motors        2,216,666.67
# Shelby          1,000,000.00
# Lotus             443,978.09
# Lamborghini       425,947.24
# Ferrari           410,099.09
# Ford              368,829.48
# Rolls-Royce       333,235.00
# McLaren           297,807.87
# Ultima            220,000.00
# Bentley           215,629.00
# Aston Martin      215,079.10
# Mercedes-AMG      169,363.64
# Mercedes-Benz     164,661.39
# Acura             157,874.06
# Polestar          155,000.00
# Maserati          145,475.21
# Tesla             143,057.50
# TVR               140,500.00
# Porsche           129,409.30
# Audi               93,874.93
# Lexus              93,228.85
# Jaguar             83,118.33
# BMW                80,134.13
# Ariel              75,000.00
# Alfa Romeo         74,134.06
# Alpine             71,500.00
# Dodge              70,976.83
# ...

# %%
pd.set_option('display.float_format', '{:,.2f}'.format)
df.groupby('Brand')['Price'].mean().sort_values(ascending=False)
# Out:
# Brand
# Bugatti         3,263,409.09
# Koenigsegg      2,906,666.67
# Pagani          2,791,666.67
# Pininfarina     2,500,000.00
# Rimac           2,400,000.00
# W Motors        2,216,666.67
# Shelby          1,000,000.00
# Lotus             508,435.86
# Lamborghini       425,947.24
# Ferrari           410,099.09
# Ford              368,829.48
# Rolls-Royce       333,235.00
# McLaren           297,807.87
# Ultima            220,000.00
# Bentley           215,629.00
# Aston Martin      215,079.10
# Mercedes-AMG      169,363.64
# Mercedes-Benz     164,661.39
# Acura             157,874.06
# Polestar          155,000.00
# Maserati          145,475.21
# Tesla             140,684.00
# TVR               140,500.00
# Porsche           129,478.41
# Audi               93,874.93
# Lexus              93,228.85
# Jaguar             83,118.33
# BMW                80,134.13
# Ariel              75,000.00
# Alfa Romeo         74,134.06
# Alpine             71,500.00
# Dodge              70,976.83
# ...

# %% [markdown]
# 5.2 Show the Mean horsepower and price across brands

# %%
df.groupby('Brand')[['Horsepower', 'Price']].mean().sort_values(by= 'Price', ascending=False)
# Out:
#                Horsepower        Price
# Brand
# Bugatti          1,502.32 3,263,409.09
# Koenigsegg       1,364.13 2,906,666.67
# Pagani             758.33 2,791,666.67
# Pininfarina      1,873.00 2,500,000.00
# Rimac            1,910.29 2,400,000.00
# W Motors           793.33 2,216,666.67
# Shelby             435.00 1,000,000.00
# Lotus              683.63   508,435.86
# Lamborghini        713.08   425,947.24
# Ferrari            795.67   410,099.09
# Ford               612.46   368,829.48
# Rolls-Royce        611.80   333,235.00
# McLaren            625.08   297,807.87
# Ultima           1,200.00   220,000.00
# Bentley            603.44   215,629.00
# Aston Martin       592.86   215,079.10
# Mercedes-AMG       584.55   169,363.64
# Mercedes-Benz      559.78   164,661.39
# Acura              573.00   157,874.06
# Polestar           600.00   155,000.00
# Maserati           460.96   145,475.21
# Tesla            1,018.00   140,684.00
# TVR                500.00   140,500.00
# ...

# %% [markdown]
# 5.3 Create a Pivot table showing the distribution of Car Models by Car Make and Price_Category

# %%
pivot_table = pd.pivot_table(
    df,
    values='Model',
    index='Brand',
    columns='Price_Category',
    aggfunc='count',
    margins = 'sum',
    margins_name = 'Total'
).sort_values(by = 'Total', ascending=False)

pivot_table
# Out:
# /tmp/ipython-input-476904906.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_table = pd.pivot_table(
# Price_Category  Budget  Mid-Range  Premium  Luxury  Total
# Brand
# Total                9        110      251     626    996
# Porsche              0          6       30      52     88
# McLaren              0          0        0      75     75
# Audi                 0          6       28      37     71
# Lamborghini          0          0        0      66     66
# BMW                  0         19       29      15     63
# Chevrolet            4         23       33       0     60
# Ferrari              0          0        0      55     55
# Mercedes-Benz        0          2       17      35     54
# Aston Martin         0          0        0      50     50
# ...

# %% [markdown]
# Create a pivot table showing the average price per car brand and engine type (Gas vs. Electric/Hybrid)

# %%
df.groupby(['Brand','Engine_Type'])['Price'].mean().sort_values(ascending=False)
# Out:
# Brand          Engine_Type
# Bugatti        Gas               3,263,409.09
# Koenigsegg     Gas               2,906,666.67
# Pagani         Gas               2,791,666.67
# Pininfarina    Electric/Hybrid   2,500,000.00
# Lotus          Electric/Hybrid   2,475,000.00
# Rimac          Electric/Hybrid   2,400,000.00
# W Motors       Gas               2,216,666.67
# Shelby         Gas               1,000,000.00
# Ferrari        Electric/Hybrid     625,000.00
# Lamborghini    Gas                 425,947.24
# Ferrari        Gas                 406,119.44
# Ford           Gas                 368,829.48
# Rolls-Royce    Gas                 333,235.00
# McLaren        Gas                 297,807.87
# Ultima         Gas                 220,000.00
# Bentley        Gas                 215,629.00
# Aston Martin   Gas                 215,079.10
# Mercedes-AMG   Gas                 169,363.64
# Mercedes-Benz  Gas                 164,661.39
# Acura          Gas                 157,874.06
# ...

# %% [markdown]
# ## 🧠 6. Analysis Questions  & 📈 Data Visualization
# Answer the following using both data analysis and graphs:
# 1. Which **brand** has the most expensive sports cars on average?
# 2. Is there a strong correlation between **horsepower** and **price**?
# 3. How does **0-60 MPH Time** influence car pricing?
# 4. Do newer cars tend to have higher prices?

# %%
ave_price_brand = df.groupby('Brand', as_index=False)['Price'].mean().sort_values(by='Price', ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(y='Brand', x='Price', data=ave_price_brand, orient='h')
plt.title('Average Price per Car Brand')
plt.xlabel('Average Price in Millions')
plt.ylabel('Car Make')
# Out:
# Text(0, 0.5, 'Car Make')

# %%
df.plot(
    x = "Horsepower",
    y = "Price",
    kind = "scatter",
    figsize = (10,6)
)
# Out:
# <Axes: xlabel='Horsepower', ylabel='Price'>

# %%
df.plot(
    x = "0-60",
    y = "Price",
    kind = "scatter",
    figsize = (10,6)
)
# Out:
# <Axes: xlabel='0-60', ylabel='Price'>

# %%
sns.histplot(df['Car_Age'], bins=50, kde=True)
# Out:
# <Axes: xlabel='Car_Age', ylabel='Count'>

# %%
avg_price_year = df.groupby('Car_Age')['Price'].mean().sort_index()

plt.figure(figsize=(10,6))
plt.bar(avg_price_year.index, avg_price_year.values)
plt.xlabel('Year')
plt.ylabel('Average Price')
plt.title('Average Car Price per Year')
plt.show()

# %%
avg_price_year = df.groupby('Car_Age')['Price'].mean()


avg_price_year.plot(kind = "line",
    figsize = (10,6)
)
# Out:
# <Axes: xlabel='Car_Age'>
