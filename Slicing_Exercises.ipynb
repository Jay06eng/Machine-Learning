# %% [markdown]
# <a href="https://colab.research.google.com/github/Jay06eng/Machine-Learning/blob/main/Slicing_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🏋️‍♀️ Python Slicing Practice Exercises
# Welcome to the slicing practice notebook! Complete each of the exercises below. Try not to use AI resources until you’ve attempted the problem yourself.
#
# ---

# %% [markdown]
# ## 🔹 Exercise 1: String Basics
# Given the string below, extract the word `Python`.

# %%
text = "I am learning Python programming"
# Your code here to slice 'Python'

# %% [markdown]
# ## 🔹 Exercise 2: Last Characters
# Slice the last 4 characters from the string.

# %%
quote = "Simplicity is the soul of efficiency"
# Your code here

# %% [markdown]
# ## 🔹 Exercise 3: Every Other Letter
# Use slicing to print every second character of the string.

# %%
phrase = "DataScience"
# Your code here

# %% [markdown]
# ## 🔹 Exercise 4: Reverse the String
# Reverse the string using slicing.

# %%
name = "ColabNotebook"
# Your code here

# %% [markdown]
# ## 🔹 Exercise 5: Middle Slice
# Slice the word `program` from the string below.

# %%
sentence = "I love to program in Python"
# Your code here

# %% [markdown]
# ## 🔹 Exercise 6: List Slice
# From the list below, extract elements `[30, 40, 50]`.

# %%
numbers = [10, 20, 30, 40, 50, 60, 70]
# Your code here

# %% [markdown]
# ## 🔹 Exercise 7: Tuple Reverse
# Reverse the tuple using slicing.

# %%
t = ('x', 'y', 'z', 'w')
# Your code here

# %% [markdown]
# ## 🔹 Exercise 8: Custom Step
# Slice the list using a step of 2.

# %%
odds = list(range(1, 20, 2))
# Your code here

# %% [markdown]
# ## 🔹 Exercise 9: Remove Last Element
# Use slicing to create a new list without the last item.

# %%
colors = ['red', 'green', 'blue', 'yellow']
# Your code here

# %% [markdown]
# ## 🔹 Exercise 10: Challenge - Word Puzzle
# Slice `dancing` from the string below.

# %%
text = "I was daydreaming about dancing in the rain."
# Your code here

# %% [markdown]
# ---
# 🎉 **Great Job!**
# Once you're done, try creating your own slicing challenges for more practice.
